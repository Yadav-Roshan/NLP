# %% [markdown]
# <a href="https://colab.research.google.com/github/Yadav-Roshan/NLP/blob/main/youtube_comments_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import googleapiclient.discovery

# %%
API_KEY = "AIzaSyAvvbFilugjH_gYFEVweVZ_G_zUpdUez-I"
API_SERVICE_NAME = "youtube"
API_VERSION = "v3"

# %%
VIDEO_ID = "k9N_MBLVIKA"

# %%
youtube = googleapiclient.discovery.build(API_SERVICE_NAME, API_VERSION, developerKey = API_KEY)

request = youtube.commentThreads().list(
    part = "snippet, replies",
    videoId = VIDEO_ID
)

response = request.execute()

response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'EOIiFbsj5KVnpzBusnrSaF8Ljnk',
#  'pageInfo': {'totalResults': 3, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Gft6uhc8hz9wHz8jRPX4JZ2gzq0',
#    'id': 'Ugyuefu5P3UC6lRtVF94AaABAg',
#    'snippet': {'videoId': 'k9N_MBLVIKA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'uelaQElMNOB44jjMzG3zhqGtHEI',
#      'id': 'Ugyuefu5P3UC6lRtVF94AaABAg',
#      'snippet': {'videoId': 'k9N_MBLVIKA',
#       'textDisplay': 'In the current google-developers page I&#39;m not finding how to get to the CommentThreads from the reference tab as shown at time marker <a href="https://www.youtube.com/watch?v=k9N_MBLVIKA&amp;t=2m38s">2:38</a> minutes into the video. Please advise.',
#       'textOriginal': "In the current google-developers page I'm not finding how to get to the CommentThreads from the reference tab as shown at time marker 2:38 minutes into the video. Please advise.",
# ...

# %%
df = pd.json_normalize(response['items'])

# %%
df
# Out:
#                     kind                         etag  \
# 0  youtube#commentThread  Gft6uhc8hz9wHz8jRPX4JZ2gzq0
# 1  youtube#commentThread  9BC6fNF3QlcC_PL8L6zocLTKhKc
# 2  youtube#commentThread  DW8fSMMzK6Vo2B-1Zuvs98vrtCY
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  Ugyuefu5P3UC6lRtVF94AaABAg     k9N_MBLVIKA              youtube#comment
# 1  UgxEfpGc5ayfJYG6pCp4AaABAg     k9N_MBLVIKA              youtube#comment
# 2  Ugzl-EfLb25FIyabdUd4AaABAg     k9N_MBLVIKA              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  uelaQElMNOB44jjMzG3zhqGtHEI  Ugyuefu5P3UC6lRtVF94AaABAg
# 1  SHzza6vb0CXl-2ZWZP8Wyz_wGE0  UgxEfpGc5ayfJYG6pCp4AaABAg
# 2  FHy6-rwF7ggQHzSDUgZTbmuvsag  Ugzl-EfLb25FIyabdUd4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             k9N_MBLVIKA
# 1                             k9N_MBLVIKA
# 2                             k9N_MBLVIKA
#
# ...

# %%
df.columns = df.columns.str.removeprefix("snippet.").str.removeprefix('topLevelComment.').str.removeprefix("snippet.").str.removesuffix('.value').str.removesuffix('.comments')

# %%
df
# Out:
#                     kind                         etag  \
# 0  youtube#commentThread  Gft6uhc8hz9wHz8jRPX4JZ2gzq0
# 1  youtube#commentThread  9BC6fNF3QlcC_PL8L6zocLTKhKc
# 2  youtube#commentThread  DW8fSMMzK6Vo2B-1Zuvs98vrtCY
#
#                            id      videoId             kind  \
# 0  Ugyuefu5P3UC6lRtVF94AaABAg  k9N_MBLVIKA  youtube#comment
# 1  UgxEfpGc5ayfJYG6pCp4AaABAg  k9N_MBLVIKA  youtube#comment
# 2  Ugzl-EfLb25FIyabdUd4AaABAg  k9N_MBLVIKA  youtube#comment
#
#                           etag                          id      videoId  \
# 0  uelaQElMNOB44jjMzG3zhqGtHEI  Ugyuefu5P3UC6lRtVF94AaABAg  k9N_MBLVIKA
# 1  SHzza6vb0CXl-2ZWZP8Wyz_wGE0  UgxEfpGc5ayfJYG6pCp4AaABAg  k9N_MBLVIKA
# 2  FHy6-rwF7ggQHzSDUgZTbmuvsag  Ugzl-EfLb25FIyabdUd4AaABAg  k9N_MBLVIKA
#
#                                          textDisplay  \
# 0  In the current google-developers page I&#39;m ...
# 1                   Thank You for your great help!!!
# ...

# %%
df.columns
# Out:
# Index(['kind', 'etag', 'id', 'videoId', 'kind', 'etag', 'id', 'videoId',
#        'textDisplay', 'textOriginal', 'authorDisplayName',
#        'authorProfileImageUrl', 'authorChannelUrl', 'authorChannelId',
#        'canRate', 'viewerRating', 'likeCount', 'publishedAt', 'updatedAt',
#        'canReply', 'totalReplyCount', 'isPublic', 'replies'],
#       dtype='object')

# %%
df = df[['id', 'textDisplay', 'textOriginal', 'viewerRating', 'likeCount', 'replies']]
df
# Out:
#                            id                          id  \
# 0  Ugyuefu5P3UC6lRtVF94AaABAg  Ugyuefu5P3UC6lRtVF94AaABAg
# 1  UgxEfpGc5ayfJYG6pCp4AaABAg  UgxEfpGc5ayfJYG6pCp4AaABAg
# 2  Ugzl-EfLb25FIyabdUd4AaABAg  Ugzl-EfLb25FIyabdUd4AaABAg
#
#                                          textDisplay  \
# 0  In the current google-developers page I&#39;m ...
# 1                   Thank You for your great help!!!
# 2  Great content sir ! Requesting you to kindly c...
#
#                                         textOriginal viewerRating  likeCount  \
# 0  In the current google-developers page I'm not ...         none          0
# 1                   Thank You for your great help!!!         none          1
# 2  Great content sir ! Requesting you to kindly c...         none          0
#
#                                              replies
# 0                                                NaN
# 1  [{'kind': 'youtube#comment', 'etag': 'tDXHLe_A...
# ...

# %%
df_replies = pd.json_normalize(df['replies'][2][0]['snippet'])

# %%
df['replies'][2][0]['id'].split(".")[1]
# Out:
# '9gsT0j__7XD9gsuzsPz1n3'
